# %% [markdown]
# <a href="https://colab.research.google.com/github/MagnusFelinto/hub/blob/master/Imer%C3%A7%C3%A3o_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 01

# %%
import pandas as pd
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

# %%
dados = pd.read_csv(url_dados, compression ='zip') 
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados["tratamento"]
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %% [markdown]
# ###Desafio 01 Invesigar por que a classe tratamento é tão desbalanceada?
#
# ###Desafio 02 Mostras as 5 ultimas linhas.
#
# ###Desafio 03 Propoção das classes tratamento.
#
# ###Desafio 04 Quantas drogas foram usadas?
#
# ###Desafio 05 Procura na documentação o metodo query (pandas)
#
# ###Desafio 06 Renomear as colunas tirando o hífen.
#
# ###Desafio 07 Nomear os graficos (Matplotlib.pyplot)
#
# ###Desafio 08 Resumo do que você aprendeu.

# %% [markdown]
# ###Desafio 01

# %%
"Na minha visão pois se trata de muitos remedios colocados na msm situação(ambiente) por se trata de menos ambientes precisa de menos controles.Ex; Para cada ambiente q as celulas se encontravam fora colocados um de controle e 20(varios) de drogas"
# Out:
# 'Na minha visão pois se trata de muitos remedios colocados na msm situação(ambiente) por se trata de menos ambientes precisa de menos controles.Ex; Para cada ambiente q as celulas se encontravam fora colocados um de controle e 20(varios) de drogas'

# %% [markdown]
# ###Desafio 02

# %%
dados.head
# Out:
# <bound method NDFrame.head of                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 03

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['droga'].value_counts(normalize = True)
# Out:
# cacb2b860    0.078357
# 87d714366    0.030150
# 9f80f3f77    0.010330
# 8b87a7a83    0.008524
# 5628cb3ee    0.008482
#                ...
# 3276db5ea    0.000042
# 828099693    0.000042
# 18a406358    0.000042
# a6334fda8    0.000042
# 796f6988f    0.000042
# Name: droga, Length: 3289, dtype: float64

# %% [markdown]
# ###Desafio 04

# %%
dados['droga'].value_counts().size
# Out:
# 3289

# %% [markdown]
# ###Desafio 05

# %%
dados[dados['g-2'] > 0]
#acho q é istoXD
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# 12     id_0025c5949     com_droga     48   D1  ...  0.8592  0.2429  0.3453  0.3083
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23803  id_fff485da4     com_droga     48   D1  ... -0.0557  0.6457 -0.4622  0.8154
# 23806  id_fff790a17     com_droga     48   D2  ...  1.2630  0.7823 -0.6947  0.7277
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
# ###Desafio 06

# %%
dados = dados.rename(columns={'g-0': 'g0', 'g-1': 'g1'}) #n encontrei um modo de modifica varias colunas ao mesmo tempo
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ###Desafio 07

# %% [markdown]
# ###Desafio 08

# %%
"Genetica <3  e um pouco de python <3 e basicamente tudo q ta acima "
# Out:
# 'Genetica <3  e um pouco de python <3 e basicamente tudo q ta acima '

# %% [markdown]
# ###Graficos

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['droga'].value_counts().plot.pie()

# %%
dados['dose'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tratamento'].value_counts().plot.bar()

# %%
dados['dose'].value_counts().plot.bar()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados['dose'].value_counts().plot.bar()

# %%
dados_filt = dados[dados['g0'] > 0]

# %%
dados_filt.size
# Out:
# 10321413

# %%
dados_filt.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# #Aula 2

# %%
mapa = {'droga':'composto'}
dados.rename(columns=mapa, inplace=True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure(figsize=(8,6))
ax = sns.countplot(x = 'composto',data=dados.query('composto in @cod_compostos')) 
ax.set_title('Top Cinco Compostos')
plt.show()

# %%
len(dados['g0'].unique())
# Out:
# 14367

# %%
dados['g0'].min()
# Out:
# -5.513

# %%
dados['g0'].max()
# Out:
# 10.0

# %%
dados['g0'].mean()
# Out:
# 0.24836629293692816

# %%
dados.describe()
# Out:
#               tempo            g0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados['g0'].hist(bins = 150)

# %%
dados[['g0', 'g1']]
# Out:
#            g0      g1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:,'g0':'g-771'].describe()
# Out:
#                  g0            g1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:,'g0':'g-771'].describe().T['mean'].hist(bins=50)

# %%
dados.loc[:,'g0':'g-771'].describe().T['min'].hist(bins=50)

# %%
dados.loc[:,'g0':'g-771'].describe().T['max'].hist(bins=50)

# %%
dados.loc[:,'c-0':'c-99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x='g0' ,data=dados)

# %%
sns.boxenplot(x= 'g0',data=dados)

# %%
sns.boxplot(x='g0', y='tratamento' ,data=dados)

# %%
sns.boxplot(y='g0', x='tratamento' ,data=dados)

# %% [markdown]
# ###Desafio 01 Ordenar o grafico countplot (1°, 2°...).
#
# ###Desafio 02 Melhorar a visualização alterando o tamanho da fonte.
#
# ###Desafio 03 Plotar os histogramas com seaborn
#
# ###Desafio 04 Estudar sobre as estatiticas retornadas no .describe()
#
# ###Desafio 05 Refletir sobre a manipulação do tamanho da visualizações.
#
# ###Desafio 06 fazer outras analises com o boxplot e o histograma
#
# ###Desafio 07 Resumo do que apreendemos

# %% [markdown]
# ##Desafio 01

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dados['composto'].value_counts()[:5].plot(kind="bar")
plt.show()

# %%
import seaborn as sns; sns.set(style='darkgrid')
import matplotlib.pyplot as plt

df = sns.load_dataset('titanic')

df['class'].value_counts().plot(kind="bar")

plt.show()

# %% [markdown]
# ##Desafio 02 03

# %%
x = dados['g0'][:5]
sns.displot(x);
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
sns.set
plt.show()

# %% [markdown]
# #Resumo do que apreendeu

# %%
"Verifique todo o codigo talvez o erro não esteja onde vc imagina "
# Out:
# 'Verifique todo o codigo talvez o erro não esteja onde vc imagina '
